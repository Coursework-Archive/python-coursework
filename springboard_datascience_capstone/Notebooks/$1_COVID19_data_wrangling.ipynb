# %% [markdown]
# [Project Proposal](https://drive.google.com/file/d/1ABrZ6iSLFORXnjAhLxxPRJnzdsiOJnfb/view?usp=sharing)

# %% [markdown]
# # 2 Data Wrangling<a id='2_Data_wrangling'></a>

# %% [markdown]
# ## 2.1 Contents<a id='2.1_Contents'></a>
# * [2 Data Wrangling](#2_Data_Wrangling)
#   * [2.1 Contents](#2.1_Contents)
#   * [2.2 Introduction](#2.2_Introduction)
#     * [2.2.1 Recap Of Data Science Problem](#2.2.1_Recap_Of_Data_Science_Problem)
#     * [2.2.2 Metadata](#2.2.2_Metadata)
#   * [2.3 Imports](#2.3_Imports)
#   * [2.4 Objectives](#2.4_Objectives)
#   * [2.5 Load the Vaccine Data](#2.5_Load_the_Vaccine_Data)
#   * [2.6 Explore the Data](#2.6_Explore_the_Data)
#     * [2.6.1 Isolate Missing Data](#2.6.1_Isolate_missing_data)
#     * [2.6.2 Find the date-range of the data](#2.6.2_Find_the_date-range_of_the_data)
#     * [2.6.3 Remove Duplicates](#2.6.3_Remove_Duplicates)
#     * [2.6.4 Numeric Features](#2.6.4_Numeric_Features)
#       * [2.6.4.1 Calculate Cumulative Vaccination Totals](#2.6.4.1_Calculate_Cumulative_Vaccination_Totals)
#       * [2.6.4.2 Distribution of Vaccine Totals by Country](#2.6.4.2_Distribution_of_Vaccine_Totals_by_Country)
#       * [2.6.4.3 Calculate Ratios Based on Daily Vaccinations](#2.6.4.3_Calculate_Ratios_Based_on_Daily_Vaccinations)
#     * [2.6.5 Categorical Features](#2.6.5_Categorical_Features)
#       * [2.6.5.1 Unique Vaccines](#2.6.5.1_Unique_Vaccines)
#         * [2.6.5.1.1 Covaxin Frequency](#2.6.5.1.1_Covaxin_Frequency)
#         * [2.6.5.1.2 EpiVacCorona Frequency](#2.6.5.1.2_EpiVacCorona_Frequency)
#         * [2.6.5.1.3 Johnson&Johnson Frequency](#2.6.5.1.3_Johnson&Johnson_Frequency)
#         * [2.6.5.1.4 Maderna Frequency](#2.6.5.1.4_Maderna_Frequency)
#         * [2.6.5.1.5 Oxford/AstraZeneca Frequency](#2.6.5.1.5_Oxford/AstraZeneca_Frequency)
#         * [2.6.5.1.6 Pfizer/BioNTech Frequency](#2.6.5.1.6_Pfizer/BioNTech_Frequency)
#         * [2.6.5.1.7 Sinopharm/Beijing Frequency](#2.6.5.1.7_Sinopharm/Beijing_Frequency)
#         * [2.6.5.1.8 Sinopharm/Wuhan Frequency](#2.6.5.1.8_Sinopharm/Wuhan_Frequency)
#         * [2.6.5.1.9 Sinovac Frequency](#2.6.5.1.9_Sinovac_Frequency)
#         * [2.6.5.1.10 Sputnik V Frequency](#2.6.5.1.10_Sputnik_V_Frequency)
#       * [2.6.5.2 Vaccines in Central America](#2.6.5.2_Vaccines_in_Central_America_Vaccinations)
#     * [2.6.6 Combining the Categorical Data](#2.6.6_Combining_the_Categorical_Data)
#       * [2.6.6.1 Selecting Country Regions](#2.6.6.1_Selecting_Country_Regions)
#   * [2.7 Load the COVID-19 Cases Data](#2.7_Load_the_COVID-19_Cases_Data)
#   * [2.8 Explore the Data](#2.8_Explore_the_Data)
#       * [2.8.1 Numerical Data](#2.8.1_Numerical_Data)
#         * [2.8.1.1 Missing COVID-19 Values](#2.8.1.1_Missing_COVID-19_Values)
#         * [2.8.1.2 Negative Vaccine Data](#2.8.1.2_Negative_Vaccine_Data)
#         * [2.8.1.3 Negative COVID-19 Data](#2.8.1.3_Negative_COVID-19_Data)
#         * [2.8.1.4 Calculation of Active Cases](#2.8.1.4_Calculation_of_Active_Cases)
#         * [2.8.1.5 Numbers Between 1 and 0](2.8.1.5_Numbers_Between_1_and_0)
#       * [2.8.2 Categorical Data](#2.8.2_Categorical_Data)
#         * [2.8.2.1 Countries in COVID-19 Data](#2.8.2.1_Countries_in_COVID-19_Data)
#       * [2.8.3 World COVID-19 Distribution](#2.8.3_World_COVID-19_Distribution)
#         * [2.8.3.1 Coastal Asian Active COVID-19 Cases](#2.8.3.1_Coastal_Asian_Active_COVID-19_Cases)
#   * [2.9 Load the World Population Data](#2.9_Load_the_World_Population_Data)
#   * [2.10 Normalizing the Data](#2.10_Normalizing_the_Data)
#   * [2.11 Convert Datatypes](#2.11_Convert_Data_Types)
#   * [2.12 Save data](#2.12_Save_data)
#   * [2.13 Summary](#2.13_Summary)

# %% [markdown]
# ## 2.2 Introduction<a id='2.2_Introduction'></a>

# %% [markdown]
# In this notebook the data that is present will be defined and organized. There will be clear column labels and in effort to reduce the amount of computational errors the calculations will be verified and corrected if inaccurate. Any deletion and modification of the data will be summarized and the csv files that are generated from the cleaned data will be explained throughout this notebook.

# %% [markdown]
# ### 2.2.1 Recap Of Data Science Problem<a id='2.2.1_Recap_Of_Data_Science_Problem'></a>

# %% [markdown]
# The purpose of this data science project is to explore the effective strategies for distribution of the vaccine as the disease continues to spread. As billions of people around the world are waiting to be vaccinated, the shared responsibility to maintain a healthy environment rests on the shoulders of each individual. When the death toll from the corona virus disease (COVID-19) was determined to be unstoppable there were many rules put in place. This shifted the focus of communities around the world to emphasize biosafety governance.
#
# Knowing very little about the data at this stage there are some questions that I would like answered:
#
#     -Vaccine distribution by country
#     -Total number of vaccines that have been distributed
#     -Confirmed cases, deaths
#     -Population comparison and vaccine distribution
#
# Each country's medical infrastructure continues to play a vital role for everyone. In the rare instance of this pandemic the data that has been captured can result in a good approximation of how the current technological advancements help reduce the time that it takes to control the spread of the disease. The health and status of each country is changing constantly and could never be understood fully when contemplating the epidemiology with reference to one disease.

# %% [markdown]
# ### 2.2.2 Metadata<a id='2.2.2_Metadata'></a>

# %% [markdown]
# Here is some important metadata for the imported datafiles:
#
# **COVID-19 World Vaccination Progress (country_vaccinations.csv)**
# * Date Created: 2021-01-12
# * Last Updated: 2021-03-02
# * Download Date: 2021-03-02
#
#
# **COVID-19 cases by Continent (covid_case_files folder with csv files, World_population(2020).csv)**
# * Date Created: 2020-04-08
# * Last Updated: 2020-12-31
# * Download Date: 2021-03-02
#
# The information in this notebook will be treated as a living document and it is necessary to be reminded that this is historical data. Best practice will be followed to commit changes using Git version control.

# %% [markdown]
# ## 2.3 Imports<a id='2.3_Imports'></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import numpy as np

#This library was created by the author of DataScienceGuidedCapstone found in my GitHub repository
#It has been used in this notebook for the sole purpose of saving files
from library.sb_utils import save_file

# %% [markdown]
# ## 2.4 Objectives<a id='2.4_Objectives'></a>

# %% [markdown]
# I believe the vaccine data and the covid cases will be sufficient to tackle the desired questions listed above. This is more of a documentation of the expanded program of immunization and how it compares to the public health records, rather than a business model. The target value that was identified in the project proposal was time dependent. The target suggests that there is potential for controlling the disease by 2022 and that people may go back to a normal way of life without masks, etc. There is some speculation about this, as well as skepticism, about the accuracy of predicting the eradication of a disease. There is far more information about the disease cases versus the vaccination. This is a fundamental difference that could not be corrected because this was a novel virus. The vaccines that were developed were barely approved within this dataset timespan. The information that is given for the vaccines could not be any greater.

# %% [markdown]
# ## 2.5 Load The Vaccine data <a id='2.5_Load_the_Vaccine_Data'></a>

# %%
#the supplied CSV file is in the raw_data directory and was uploaded from kaggle: 
#https://www.kaggle.com/gpreda/covid-world-vaccination-progress
vaccine_data = pd.read_csv('../raw_data/country_vaccinations.csv')
vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4678 entries, 0 to 4677
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4678 non-null   object
#  1   iso_code                             4366 non-null   object
#  2   date                                 4678 non-null   object
#  3   total_vaccinations                   3054 non-null   float64
#  4   people_vaccinated                    2595 non-null   float64
#  5   people_fully_vaccinated              1746 non-null   float64
#  6   daily_vaccinations_raw               2576 non-null   float64
#  7   daily_vaccinations                   4518 non-null   float64
#  8   total_vaccinations_per_hundred       3054 non-null   float64
#  9   people_vaccinated_per_hundred        2595 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1746 non-null   float64
#  11  daily_vaccinations_per_million       4518 non-null   float64
#  12  vaccines                             4678 non-null   object
#  13  source_name                          4678 non-null   object
#  14  source_website                       4678 non-null   object
# dtypes: float64(9), object(6)
# memory usage: 548.3+ KB

# %% [markdown]
# ## 2.6 Explore The Data<a id='2.6_Explore_the_Data'></a>

# %% [markdown]
# At first glance, there are some missing values, the total number of rows is 4678. None of the columns containing datatypes have a complete set. The closest to a complete set for data, in decimals, is the daily vaccinations column. There is only one column that contains object data that is not complete and that is the iso_code column.

# %%
vaccine_data.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.00                           0.00
# 3                            0.01                           0.01
# 4                            0.01                           0.01
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
# 3                                  NaN                            22.0
# 4                                  NaN                            23.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
# 3  Pfizer/BioNTech  Ministry of Health
# 4  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...
# 1  https://shendetesia.gov.al/covid19-ministria-e...
# 2  https://shendetesia.gov.al/covid19-ministria-e...
# 3  https://shendetesia.gov.al/covid19-ministria-e...
# 4  https://shendetesia.gov.al/covid19-ministria-e...

# %% [markdown]
# Looking a bit deeper, there are two columns that have daily vaccinations, one labeled daily vaccinations raw and the other daily vaccinations. This raises some questions about what exactly is being recorded. Referring back to kaggle-comments, might lead to better insight into which data to keep - the data column definition was given for the following:
#
# 'daily_vaccinations_raw: daily change in the total number of doses administered.
#
# It is only calculated for consecutive days. This is a raw measure provided for data checks and transparency, but we strongly recommend that any analysis on daily vaccination rates be conducted using daily_vaccinations instead.'
#
# Upon further inspection it looks like there is a discrepancy between the total number of vaccinations (3) and daily vaccinations (7) and there are not values for each day. To get a better understanding about the cumulative totals for each country we can look at the values missing for those columns. In addition, to the iso code column, as this column contains categorical information for each data point.

# %%
countries = pd.Series(vaccine_data.country.unique())
countries
# Out:
# 0            Albania
# 1            Algeria
# 2            Andorra
# 3           Anguilla
# 4          Argentina
#            ...
# 113    United States
# 114          Uruguay
# 115        Venezuela
# 116            Wales
# 117         Zimbabwe
# Length: 118, dtype: object

# %% [markdown]
# There are 195 countries in the world and there is data for 118 countries. That is missing data for 77 countries, nearly 40% of the world data is missing.

# %% [markdown]
# ### 2.6.1 Isolate missing data<a id='2.6.1_Isolate_missing_data'></a>

# %%
missing_vaccine = vaccine_data[['iso_code','people_vaccinated','daily_vaccinations']].isnull().sum()
p_missing = missing_vaccine/len(vaccine_data) * 100
p_missing
# Out:
# iso_code               6.669517
# people_vaccinated     44.527576
# daily_vaccinations     3.420265
# dtype: float64

# %% [markdown]
# ### 2.6.2 Find the date-range of the data<a id='2.6.2_Find_the_date-range_of_the_data'></a>

# %%
collect_end_date = vaccine_data.date.max()
collect_start_date = vaccine_data.date.min()

print('start date:', collect_start_date, '|    end date:', collect_end_date)
# Out:
# start date: 2020-12-08 |    end date: 2021-03-01

# %% [markdown]
# ### 2.6.3 Remove Duplicates<a id='2.6.3_Remove_Duplicates'></a>

# %% [markdown]
# Majority of the missing values are in the people vaccinated column and not all of the iso codes have been populated. Some of the missing iso codes are for England and it was mentioned in the kaggle-comments that the UK data has doubled, they put data from each of their nation/countries (Wales, Scotland, Ireland, and England) AND from the UK itself. To address the duplication along with the missing values for the sovereign state before summing all of the vaccinations. I believe the simplest solution will be to remove the iso codes for the individual regions.

# %%
vaccine_data = vaccine_data.set_index('country')
n_vaccine_data = vaccine_data.drop(labels=['Wales','Scotland','Northern Ireland','England']).reset_index()
n_vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4366 entries, 0 to 4365
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4366 non-null   object
#  1   iso_code                             4366 non-null   object
#  2   date                                 4366 non-null   object
#  3   total_vaccinations                   2840 non-null   float64
#  4   people_vaccinated                    2381 non-null   float64
#  5   people_fully_vaccinated              1544 non-null   float64
#  6   daily_vaccinations_raw               2383 non-null   float64
#  7   daily_vaccinations                   4210 non-null   float64
#  8   total_vaccinations_per_hundred       2840 non-null   float64
#  9   people_vaccinated_per_hundred        2381 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1544 non-null   float64
#  11  daily_vaccinations_per_million       4210 non-null   float64
#  12  vaccines                             4366 non-null   object
#  13  source_name                          4366 non-null   object
#  14  source_website                       4366 non-null   object
# dtypes: float64(9), object(6)
# memory usage: 511.8+ KB

# %% [markdown]
# Now that the United Kingdom duplicated regions have been removed, the missing values for daily vaccinations can be removed and the vaccine values can be summed to populate an accurate cumulative total for total vaccinations based on the daily vaccinations column.

# %% [markdown]
# ### 2.6.4 Numeric Features<a id='2.6.4_Numeric_Features'></a>

# %% [markdown]
# #### 2.6.4.1 Calculate Cumulative Vaccination Totals<a id='2.6.4.1_Calculate_Cumulative_Vaccination_Totals'></a>

# %%
missing_vaccine_data = n_vaccine_data.dropna(subset=['daily_vaccinations'], inplace=True)
n_vaccine_data['total_vaccinations'] = n_vaccine_data.groupby('iso_code').daily_vaccinations.cumsum()
n_vaccine_data.head(50)
# Out:
#     country iso_code        date  total_vaccinations  people_vaccinated  \
# 1   Albania      ALB  2021-01-11                64.0                NaN
# 2   Albania      ALB  2021-01-12               128.0              128.0
# 3   Albania      ALB  2021-01-13               191.0              188.0
# 4   Albania      ALB  2021-01-14               257.0              266.0
# 5   Albania      ALB  2021-01-15               319.0              308.0
# 6   Albania      ALB  2021-01-16               381.0              369.0
# 7   Albania      ALB  2021-01-17               439.0              405.0
# 8   Albania      ALB  2021-01-18               494.0              447.0
# 9   Albania      ALB  2021-01-19               545.0              483.0
# 10  Albania      ALB  2021-01-20               592.0              519.0
# 11  Albania      ALB  2021-01-21               632.0              549.0
# 12  Albania      ALB  2021-01-22               666.0                NaN
# 13  Albania      ALB  2021-01-23               692.0                NaN
# 14  Albania      ALB  2021-01-24               713.0                NaN
# 15  Albania      ALB  2021-01-25               728.0                NaN
# 16  Albania      ALB  2021-01-26               737.0                NaN
# 17  Albania      ALB  2021-01-27               741.0                NaN
# 24  Albania      ALB  2021-02-03               753.0                NaN
# 25  Albania      ALB  2021-02-04               777.0                NaN
# 26  Albania      ALB  2021-02-05               812.0                NaN
# 27  Albania      ALB  2021-02-06               859.0                NaN
# 28  Albania      ALB  2021-02-07               918.0                NaN
# 29  Albania      ALB  2021-02-08               989.0                NaN
# 30  Albania      ALB  2021-02-09              1071.0              689.0
# 31  Albania      ALB  2021-02-10              1152.0                NaN
# 32  Albania      ALB  2021-02-11              1231.0                NaN
# 33  Albania      ALB  2021-02-12              1309.0                NaN
# 34  Albania      ALB  2021-02-13              1385.0                NaN
# 35  Albania      ALB  2021-02-14              1460.0                NaN
# 36  Albania      ALB  2021-02-15              1533.0                NaN
# 37  Albania      ALB  2021-02-16              1605.0                NaN
# 38  Albania      ALB  2021-02-17              1677.0             1090.0
# 39  Albania      ALB  2021-02-18              1931.0             2438.0
# 40  Albania      ALB  2021-02-19              2336.0                NaN
# 41  Albania      ALB  2021-02-20              2852.0                NaN
# 42  Albania      ALB  2021-02-21              3479.0                NaN
# 43  Albania      ALB  2021-02-22              4218.0             6073.0
# 44  Albania      ALB  2021-02-23              5109.0                NaN
# 45  Albania      ALB  2021-02-24              6152.0                NaN
# 46  Albania      ALB  2021-02-25              7164.0                NaN
# 48  Algeria      DZA  2021-01-30                30.0                NaN
# 49  Algeria      DZA  2021-01-31              1919.0                NaN
# 50  Algeria      DZA  2021-02-01              4428.0                NaN
# 51  Algeria      DZA  2021-02-02              7247.0                NaN
# 52  Algeria      DZA  2021-02-03             10252.0                NaN
# 53  Algeria      DZA  2021-02-04             13381.0                NaN
# 54  Algeria      DZA  2021-02-05             16598.0                NaN
# 55  Algeria      DZA  2021-02-06             20346.0                NaN
# 56  Algeria      DZA  2021-02-07             24094.0                NaN
# 57  Algeria      DZA  2021-02-08             27842.0                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1                       NaN                     NaN                64.0
# 2                       NaN                     NaN                64.0
# 3                       NaN                    60.0                63.0
# 4                       NaN                    78.0                66.0
# 5                       NaN                    42.0                62.0
# 6                       NaN                    61.0                62.0
# 7                       NaN                    36.0                58.0
# 8                       NaN                    42.0                55.0
# 9                       NaN                    36.0                51.0
# 10                      NaN                    36.0                47.0
# 11                      NaN                    30.0                40.0
# 12                      NaN                     NaN                34.0
# 13                      NaN                     NaN                26.0
# 14                      NaN                     NaN                21.0
# 15                      NaN                     NaN                15.0
# 16                      NaN                     NaN                 9.0
# 17                      NaN                     NaN                 4.0
# 24                      NaN                     NaN                12.0
# 25                      NaN                     NaN                24.0
# 26                      NaN                     NaN                35.0
# 27                      NaN                     NaN                47.0
# 28                      NaN                     NaN                59.0
# 29                      NaN                     NaN                71.0
# 30                    438.0                     NaN                82.0
# 31                      NaN                     NaN                81.0
# 32                      NaN                     NaN                79.0
# 33                      NaN                     NaN                78.0
# 34                      NaN                     NaN                76.0
# 35                      NaN                     NaN                75.0
# 36                      NaN                     NaN                73.0
# 37                      NaN                     NaN                72.0
# 38                    611.0                     NaN                72.0
# 39                    611.0                  1348.0               254.0
# 40                      NaN                  1128.0               405.0
# 41                      NaN                     NaN               516.0
# 42                      NaN                     NaN               627.0
# 43                    655.0                     NaN               739.0
# 44                      NaN                     NaN               891.0
# 45                      NaN                     NaN              1043.0
# 46                      NaN                     NaN              1012.0
# 48                      NaN                    30.0                30.0
# 49                      NaN                     NaN              1889.0
# 50                      NaN                     NaN              2509.0
# 51                      NaN                     NaN              2819.0
# 52                      NaN                     NaN              3005.0
# 53                      NaN                     NaN              3129.0
# 54                      NaN                     NaN              3217.0
# 55                      NaN                     NaN              3748.0
# 56                      NaN                     NaN              3748.0
# 57                      NaN                     NaN              3748.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1                              NaN                            NaN
# 2                             0.00                           0.00
# 3                             0.01                           0.01
# 4                             0.01                           0.01
# 5                             0.01                           0.01
# 6                             0.01                           0.01
# 7                             0.01                           0.01
# 8                             0.02                           0.02
# 9                             0.02                           0.02
# 10                            0.02                           0.02
# 11                            0.02                           0.02
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 24                             NaN                            NaN
# 25                             NaN                            NaN
# 26                             NaN                            NaN
# 27                             NaN                            NaN
# 28                             NaN                            NaN
# 29                             NaN                            NaN
# 30                            0.04                           0.02
# 31                             NaN                            NaN
# 32                             NaN                            NaN
# 33                             NaN                            NaN
# 34                             NaN                            NaN
# 35                             NaN                            NaN
# 36                             NaN                            NaN
# 37                             NaN                            NaN
# 38                            0.06                           0.04
# 39                            0.11                           0.08
# 40                            0.15                            NaN
# 41                             NaN                            NaN
# 42                             NaN                            NaN
# 43                            0.23                           0.21
# 44                             NaN                            NaN
# 45                             NaN                            NaN
# 46                            0.35                            NaN
# 48                            0.00                            NaN
# 49                             NaN                            NaN
# 50                             NaN                            NaN
# 51                             NaN                            NaN
# 52                             NaN                            NaN
# 53                             NaN                            NaN
# 54                             NaN                            NaN
# 55                             NaN                            NaN
# 56                             NaN                            NaN
# 57                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 1                                   NaN                            22.0
# 2                                   NaN                            22.0
# 3                                   NaN                            22.0
# 4                                   NaN                            23.0
# 5                                   NaN                            22.0
# 6                                   NaN                            22.0
# 7                                   NaN                            20.0
# 8                                   NaN                            19.0
# 9                                   NaN                            18.0
# 10                                  NaN                            16.0
# 11                                  NaN                            14.0
# 12                                  NaN                            12.0
# 13                                  NaN                             9.0
# 14                                  NaN                             7.0
# 15                                  NaN                             5.0
# 16                                  NaN                             3.0
# 17                                  NaN                             1.0
# 24                                  NaN                             4.0
# 25                                  NaN                             8.0
# 26                                  NaN                            12.0
# 27                                  NaN                            16.0
# 28                                  NaN                            21.0
# 29                                  NaN                            25.0
# 30                                 0.02                            28.0
# 31                                  NaN                            28.0
# 32                                  NaN                            27.0
# 33                                  NaN                            27.0
# 34                                  NaN                            26.0
# 35                                  NaN                            26.0
# 36                                  NaN                            25.0
# 37                                  NaN                            25.0
# 38                                 0.02                            25.0
# 39                                 0.02                            88.0
# 40                                  NaN                           141.0
# 41                                  NaN                           179.0
# 42                                  NaN                           218.0
# 43                                 0.02                           257.0
# 44                                  NaN                           310.0
# 45                                  NaN                           362.0
# 46                                  NaN                           352.0
# 48                                  NaN                             1.0
# 49                                  NaN                            43.0
# 50                                  NaN                            57.0
# 51                                  NaN                            64.0
# 52                                  NaN                            69.0
# 53                                  NaN                            71.0
# 54                                  NaN                            73.0
# 55                                  NaN                            85.0
# 56                                  NaN                            85.0
# 57                                  NaN                            85.0
#
#            vaccines         source_name  \
# 1   Pfizer/BioNTech  Ministry of Health
# 2   Pfizer/BioNTech  Ministry of Health
# 3   Pfizer/BioNTech  Ministry of Health
# 4   Pfizer/BioNTech  Ministry of Health
# 5   Pfizer/BioNTech  Ministry of Health
# 6   Pfizer/BioNTech  Ministry of Health
# 7   Pfizer/BioNTech  Ministry of Health
# 8   Pfizer/BioNTech  Ministry of Health
# 9   Pfizer/BioNTech  Ministry of Health
# 10  Pfizer/BioNTech  Ministry of Health
# 11  Pfizer/BioNTech  Ministry of Health
# 12  Pfizer/BioNTech  Ministry of Health
# 13  Pfizer/BioNTech  Ministry of Health
# 14  Pfizer/BioNTech  Ministry of Health
# 15  Pfizer/BioNTech  Ministry of Health
# 16  Pfizer/BioNTech  Ministry of Health
# 17  Pfizer/BioNTech  Ministry of Health
# 24  Pfizer/BioNTech  Ministry of Health
# 25  Pfizer/BioNTech  Ministry of Health
# 26  Pfizer/BioNTech  Ministry of Health
# 27  Pfizer/BioNTech  Ministry of Health
# 28  Pfizer/BioNTech  Ministry of Health
# 29  Pfizer/BioNTech  Ministry of Health
# 30  Pfizer/BioNTech  Ministry of Health
# 31  Pfizer/BioNTech  Ministry of Health
# 32  Pfizer/BioNTech  Ministry of Health
# 33  Pfizer/BioNTech  Ministry of Health
# 34  Pfizer/BioNTech  Ministry of Health
# 35  Pfizer/BioNTech  Ministry of Health
# 36  Pfizer/BioNTech  Ministry of Health
# 37  Pfizer/BioNTech  Ministry of Health
# 38  Pfizer/BioNTech  Ministry of Health
# 39  Pfizer/BioNTech  Ministry of Health
# 40  Pfizer/BioNTech  Ministry of Health
# 41  Pfizer/BioNTech  Ministry of Health
# 42  Pfizer/BioNTech  Ministry of Health
# 43  Pfizer/BioNTech  Ministry of Health
# 44  Pfizer/BioNTech  Ministry of Health
# 45  Pfizer/BioNTech  Ministry of Health
# 46  Pfizer/BioNTech  Ministry of Health
# 48        Sputnik V  Ministry of Health
# 49        Sputnik V  Ministry of Health
# 50        Sputnik V  Ministry of Health
# 51        Sputnik V  Ministry of Health
# 52        Sputnik V  Ministry of Health
# 53        Sputnik V  Ministry of Health
# 54        Sputnik V  Ministry of Health
# 55        Sputnik V  Ministry of Health
# 56        Sputnik V  Ministry of Health
# 57        Sputnik V  Ministry of Health
#
#                                        source_website
# 1   https://shendetesia.gov.al/covid19-ministria-e...
# 2   https://shendetesia.gov.al/covid19-ministria-e...
# 3   https://shendetesia.gov.al/covid19-ministria-e...
# 4   https://shendetesia.gov.al/covid19-ministria-e...
# 5   https://shendetesia.gov.al/covid19-ministria-e...
# 6   https://shendetesia.gov.al/covid19-ministria-e...
# 7   https://shendetesia.gov.al/covid19-ministria-e...
# 8   https://shendetesia.gov.al/covid19-ministria-e...
# 9   https://shendetesia.gov.al/covid19-ministria-e...
# 10  https://shendetesia.gov.al/covid19-ministria-e...
# 11  https://shendetesia.gov.al/covid19-ministria-e...
# 12  https://shendetesia.gov.al/covid19-ministria-e...
# 13  https://shendetesia.gov.al/covid19-ministria-e...
# 14  https://shendetesia.gov.al/covid19-ministria-e...
# 15  https://shendetesia.gov.al/covid19-ministria-e...
# 16  https://shendetesia.gov.al/covid19-ministria-e...
# 17  https://shendetesia.gov.al/covid19-ministria-e...
# 24  https://shendetesia.gov.al/covid19-ministria-e...
# 25  https://shendetesia.gov.al/covid19-ministria-e...
# 26  https://shendetesia.gov.al/covid19-ministria-e...
# 27  https://shendetesia.gov.al/covid19-ministria-e...
# 28  https://shendetesia.gov.al/covid19-ministria-e...
# 29  https://shendetesia.gov.al/covid19-ministria-e...
# 30  https://shendetesia.gov.al/covid19-ministria-e...
# 31  https://shendetesia.gov.al/covid19-ministria-e...
# 32  https://shendetesia.gov.al/covid19-ministria-e...
# 33  https://shendetesia.gov.al/covid19-ministria-e...
# 34  https://shendetesia.gov.al/covid19-ministria-e...
# 35  https://shendetesia.gov.al/covid19-ministria-e...
# 36  https://shendetesia.gov.al/covid19-ministria-e...
# 37  https://shendetesia.gov.al/covid19-ministria-e...
# 38  https://shendetesia.gov.al/covid19-ministria-e...
# 39  https://shendetesia.gov.al/covid19-ministria-e...
# 40  https://shendetesia.gov.al/covid19-ministria-e...
# 41  https://shendetesia.gov.al/covid19-ministria-e...
# 42  https://shendetesia.gov.al/covid19-ministria-e...
# 43  https://shendetesia.gov.al/covid19-ministria-e...
# 44  https://shendetesia.gov.al/covid19-ministria-e...
# 45  https://shendetesia.gov.al/covid19-ministria-e...
# 46  https://shendetesia.gov.al/covid19-ministria-e...
# 48  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 49  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 50  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 51  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 52  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 53  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 54  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 55  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 56  https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 57  https://www.echoroukonline.com/%d9%84%d9%82%d8...

# %% [markdown]
# All null values for daily vaccinations are gone, around 160 rows, and running total has been calculated per each iso code. Comparing the total vaccinations column with the people vaccinated, there are values which are misaligned, and as we saw earlier, almost half of the data is missing from the people vaccinated column. From my understanding about the data this duplication of columns would lead to more questions than answers. Also, as mentioned before the daily vaccinations raw - was simply for data checks and transparency, most of the computation will be based off of daily vaccinations. Therefore, three columns will be removed: people vaccinated, people vaccinated per hundred and daily vaccination raw.

# %%
p_vaccine_data = n_vaccine_data.drop(columns=['people_vaccinated','daily_vaccinations_raw','people_vaccinated_per_hundred'])
p_vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4210 entries, 1 to 4365
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4210 non-null   object
#  1   iso_code                             4210 non-null   object
#  2   date                                 4210 non-null   object
#  3   total_vaccinations                   4210 non-null   float64
#  4   people_fully_vaccinated              1538 non-null   float64
#  5   daily_vaccinations                   4210 non-null   float64
#  6   total_vaccinations_per_hundred       2713 non-null   float64
#  7   people_fully_vaccinated_per_hundred  1538 non-null   float64
#  8   daily_vaccinations_per_million       4210 non-null   float64
#  9   vaccines                             4210 non-null   object
#  10  source_name                          4210 non-null   object
#  11  source_website                       4210 non-null   object
# dtypes: float64(6), object(6)
# memory usage: 427.6+ KB

# %% [markdown]
# A graphical representation of the miximums from the total vaccinations per country will show us how frequently the number passes one million. This will be a deciding point on whether to keep that column or remove it.

# %% [markdown]
# #### 2.6.4.2 Distribution of Vaccine Totals by Country<a id='2.6.4.2_Distribution_of_Vaccine_Totals_by_Country'></a>

# %%
vaccine_max = p_vaccine_data.groupby('country')['total_vaccinations'].max()
vaccine_max
vaccine_max.sort_values(ascending=False).plot(kind='barh', figsize=(10, 30), title='Total Vaccine Distribution by Country DEC2020 - MAR2021')
plt.xlabel('Number of Vaccines (10M)');

# %%
more_than_mil = vaccine_max > 1000000
more_than_mil.value_counts()
# Out:
# False    89
# True     22
# Name: total_vaccinations, dtype: int64

# %%
all_rows = p_vaccine_data.total_vaccinations > 1000000
all_rows.value_counts()
# Out:
# False    3471
# True      739
# Name: total_vaccinations, dtype: int64

# %% [markdown]
# Out of the 118 countries that are listed 22 have vaccines counts that are greater than one million. It is a very optimistic outlook, given the fact that this is for a 3 month period, the other 89 cumulative calculated values would be less than one or smaller. That is to say 21% of the data will be greater than one million. The daily vaccinations per million column can be removed and new values for the total vaccinations per hundred can be calculated based on the numbers that were calculated earlier for total number of vaccinations.

# %% [markdown]
# #### 2.6.4.3 Calculate Ratios Based on Daily Vaccinations<a id='2.6.4.3_Calculate_Ratios_Based_on_Daily_Vaccinations'></a>

# %%
p_vaccine_data = p_vaccine_data.drop(columns=['daily_vaccinations_per_million'])
p_vaccine_data['total_vaccinations_per_hundred'] = p_vaccine_data['total_vaccinations'] / 100
p_vaccine_data['people_fully_vaccinated_per_hundred'] = p_vaccine_data['people_fully_vaccinated'] / 100
p_vaccine_data[['people_fully_vaccinated','people_fully_vaccinated_per_hundred']] = p_vaccine_data[['people_fully_vaccinated','people_fully_vaccinated_per_hundred']].fillna(0)
pop_v = p_vaccine_data.reset_index().drop(columns='index')
pop_v.head()
# Out:
#    country iso_code        date  total_vaccinations  people_fully_vaccinated  \
# 0  Albania      ALB  2021-01-11                64.0                      0.0
# 1  Albania      ALB  2021-01-12               128.0                      0.0
# 2  Albania      ALB  2021-01-13               191.0                      0.0
# 3  Albania      ALB  2021-01-14               257.0                      0.0
# 4  Albania      ALB  2021-01-15               319.0                      0.0
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                64.0                            0.64
# 1                64.0                            1.28
# 2                63.0                            1.91
# 3                66.0                            2.57
# 4                62.0                            3.19
#
#    people_fully_vaccinated_per_hundred         vaccines         source_name  \
# 0                                  0.0  Pfizer/BioNTech  Ministry of Health
# 1                                  0.0  Pfizer/BioNTech  Ministry of Health
# 2                                  0.0  Pfizer/BioNTech  Ministry of Health
# 3                                  0.0  Pfizer/BioNTech  Ministry of Health
# 4                                  0.0  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...
# 1  https://shendetesia.gov.al/covid19-ministria-e...
# 2  https://shendetesia.gov.al/covid19-ministria-e...
# 3  https://shendetesia.gov.al/covid19-ministria-e...
# 4  https://shendetesia.gov.al/covid19-ministria-e...

# %% [markdown]
# ### 2.6.5 Categorical Features<a id='2.6.5_Categorical_Features'></a>

# %% [markdown]
# There is now a complete numeric data set. There are multiple vaccines that are listed in each column. To determine the distribution of each vaccine the column strings must be split into individual columns. Visualizing the data by vaccine will be easier if the vaccines are split up into separate columns.

# %% [markdown]
# #### 2.6.5.1 Unique Vaccines<a id='2.6.5.1_Unique_Vaccines'></a>

# %%
#Getting unique vaccine from the vaccine column
vac_type = p_vaccine_data["vaccines"].str.split(",").explode("vaccines").unique()
vac_type_list = [x.replace(" ", '') for x in vac_type]
vac_pd = pd.DataFrame(vac_type_list).rename(columns={0:'vaccine'}).drop(index=[4,5,6,9,11]).sort_values('vaccine').reset_index()
vac_pd.drop(columns='index')
# Out:
#               vaccine
# 0             Covaxin
# 1        EpiVacCorona
# 2     Johnson&Johnson
# 3             Moderna
# 4  Oxford/AstraZeneca
# 5     Pfizer/BioNTech
# 6   Sinopharm/Beijing
# 7     Sinopharm/Wuhan
# 8             Sinovac
# 9            SputnikV

# %% [markdown]
# This is the complete set of unique vaccines and can be used to determine the total frequency each vaccine is listed in this dataset. This number can be used as a factor of total vaccines distributed per country.

# %% [markdown]
# ##### 2.6.5.1.1 Covaxin Frequency<a id='2.6.5.1.1_Covaxin_Frequency'></a>

# %%
def get_vac(vac_str):
    cov_data = p_vaccine_data["vaccines"].str.split(',', expand=True)
    cov = cov_data.values == vac_str
    cov_df = pd.DataFrame(cov)
    c_df = cov_df.replace({True:vac_str, False:''})
    return c_df

#Covaxin
c_df = get_vac('Covaxin')
c_df.describe()

#Covaxin (44/4210) was administered to India with reference to the raw data - will need to verify that after the concatonation
# Out:
#            0     1     2     3     4
# count   4210  4210  4210  4210  4210
# unique     2     1     1     1     1
# top
# freq    4166  4210  4210  4210  4210

# %% [markdown]
# ##### 2.6.5.1.2  EpiVacCorona Frequency<a id='2.6.5.1.2_EpiVacCorona_Frequency'></a>

# %%
#EpiVacCorona
e_df = get_vac('EpiVacCorona')
e_df.describe()

#EpiVacCorona (76/4210) is a Russian vaccination
# Out:
#            0     1     2     3     4
# count   4210  4210  4210  4210  4210
# unique     2     1     1     1     1
# top
# freq    4134  4210  4210  4210  4210

# %% [markdown]
# ##### 2.6.5.1.3 Johnson&Johnson Frequency<a id='2.6.5.1.3_Johnson&Johnson_Frequency'></a>

# %%
#Johnson&Johnson
jnj_df = get_vac('Johnson&Johnson')
jnj_df.describe()

#Johnson&Johnson (12/4210) is a South Afrian vaccination
# Out:
#            0     1     2     3     4
# count   4210  4210  4210  4210  4210
# unique     2     1     1     1     1
# top
# freq    4198  4210  4210  4210  4210

# %% [markdown]
# ##### 2.6.5.1.4 Maderna Frequency<a id='2.6.5.1.4_Maderna_Frequency'></a>

# %%
#Moderna
m_df = get_vac('Moderna')
m_df.describe()

#Moderna (1644/4210) was administered to Austria, Belgium, Bulgaria, Canada, Czechia, Denmark, Estonia, Finland, France, 
#Germany, Greece,Hungary, Iceland, Ireland, Israel, Italy, Latvia, Liechtenstein, Lithuania, Luxembourg, Netherlands, Norway, Poland, 
#Portugal, Romania, Spain, Switzerland, US
# Out:
#            0     1     2     3     4
# count   4210  4210  4210  4210  4210
# unique     2     1     1     1     1
# top
# freq    2566  4210  4210  4210  4210

# %% [markdown]
# ##### 2.6.5.1.5 Oxford/AstraZeneca Frequency<a id='2.6.5.1.5_Oxford/AstraZeneca_Frequency'></a>

# %%
#'Oxford/AstraZeneca'

def combine_series(s1, s2, vaccine):
    not_None = lambda s1, s2: s1 if s1 == vaccine else s2
    s = s1.combine(s2, not_None)
    return s

oxas_df = get_vac('Oxford/AstraZeneca')
oxas_df.describe()
oxas_df2 = get_vac(' Oxford/AstraZeneca')
oxas_df2.describe()

#Combining the Oxford/AstraZeneca data from two to one column
oxas_s = combine_series(oxas_df[0], oxas_df2[1], 'Oxford/AstraZeneca').str.lstrip(' ?')
oxas_s.describe()
#Oxford/AstraZeneca (2271/4210) was administered to Anguilla, Austria, Azerbaijan, Bahrain, Bangladesh, Barbados, Belgium, Brazil, 
#Bulgaria, Czechia, Dominican Republic, El Salvador, England, Estonia, Falkland Islands, Finland, France, Germany, Greece
#Guyana, Hungary, Iceland, India, Ireland, Isle of Man, Italy, Jersey, Latvia, Lithuania, Luxembourg, Maldives, Mauritius, 
#Mexico, Morocco, Myanmar, Nepal, Netherlands, Northern Ireland, Norway, Oman, Pakistan, Poland, Qatar, Romania, Saint Helena, 
#Saudi Arabia, Scotland, Seychelles, Slovenia, South Korea, Spain, Sri Lanka, Sweden, Trinidad and Tobago, Ukraine, 
#United Arab Emirates, UK, Wales
# Out:
# count                   4210
# unique                     2
# top       Oxford/AstraZeneca
# freq                    2271
# dtype: object

# %% [markdown]
# ##### 2.6.5.1.6 Pfizer/BioNTech Frequency<a id='2.6.5.1.6_Pfizer/BioNTech_Frequency'></a>

# %%
#'Pfizer/BioNTech'
pfiz_df = get_vac('Pfizer/BioNTech')
pfiz_df.describe()
pfiz_df2 = get_vac(' Pfizer/BioNTech')
pfiz_df2.describe()

#Combining the Pfizer/BioNTech data from three to one column
pre_pfiz_s = combine_series(pfiz_df2[1], pfiz_df2[2], ' Pfizer/BioNTech')
pfiz_s = combine_series(pfiz_df[0], pre_pfiz_s, 'Pfizer/BioNTech').str.lstrip(' ?')
pfiz_s.describe()

#Pfizer/BioNTech (3270/4210) was administered to Albania, Andorra, Australia, Austria, Bahrain, Belgium, Bermuda,Bulgaria, 
#Canada, Cayman Islands, Chile, Colombia, Costa Rica, Croatia, Cyprus, Czechia, Ecuador, England, Estonia, Faeroe Islands,
#Finland, France, Germany, Gibraltar, Greece, Greenland, Guernsey, Hong Kong, Hungary, Iceland, Ireland, Isle of Man, 
#Israel, Italy, Japan, Jersey, Jordan, Kuwait, Latvia, Lebanon, Liechtenstein, Lithuania, Luxembourg, Malta, Mexico, 
#Monaco, Netherlands, New Zealand, Northern Ireland, Norway, Oman, Panama, Poland, Portugal, Qatar, Romania, Saudi Arabia, 
#Scotland, Serbia, Singapore, Slovakia, Slovenia, Spain, Sweden, Switzerland, Turks and Caicos Islands, United Arab Emirates,
#UK, US, Wales
# Out:
# count                4210
# unique                  2
# top       Pfizer/BioNTech
# freq                 3270
# dtype: object

# %% [markdown]
# ##### 2.6.5.1.7 Sinopharm/Beijing Frequency<a id='2.6.5.1.7_Sinopharm/Beijing_Frequency'></a>

# %%
#'Sinopharm/Beijing'
sbe_df = get_vac('Sinopharm/Beijing')
sbe_df.describe()
sbe_df2 = get_vac(' Sinopharm/Beijing')
sbe_df2.describe()

#Combining the Sinopharm/Beijing data from four to one column
c3n2_sbe_s = combine_series(sbe_df2[3], sbe_df2[2], ' Sinopharm/Beijing')
c3n2n1_sbe_s = combine_series(c3n2_sbe_s, sbe_df2[1], ' Sinopharm/Beijing')
sbe_s = combine_series(sbe_df[0], c3n2n1_sbe_s, 'Sinopharm/Beijing').str.lstrip(' ?')
sbe_s.describe()

#Sinopharm/Beijing (502/4210) was administered to Bahrain, Cambodia, China, Egypt, Hungary, Jordan, Macao, Morocco, Pakistan, Peru, 
#Senegal, Serbia, Seychelles, United Arab Emirates, Zimbabwe
# Out:
# count     4210
# unique       2
# top
# freq      3708
# dtype: object

# %% [markdown]
# ##### 2.6.5.1.8 Sinopharm/Wuhan Frequency<a id='2.6.5.1.8_Sinopharm/Wuhan_Frequency'></a>

# %%
#'Sinopharm/Wuhan'
swu_df = get_vac(' Sinopharm/Wuhan')
swu_df.describe()

#Combining the Sinopharm/Wuhan data from two to one column
swu_s = combine_series(swu_df[1], swu_df[3], ' Sinopharm/Wuhan')
swu_s.describe()

#Sinopharm/Wuhan (111/4210) was administered to China and United Arab Emirates
# Out:
# count     4210
# unique       2
# top
# freq      4099
# dtype: object

# %% [markdown]
# ##### 2.6.5.1.9 Sinovac Frequency<a id='2.6.5.1.9_Sinovac_Frequency'></a>

# %%
#'Sinovac'
sin_df = get_vac('Sinovac')
sin_df.describe()
sin_df2 = get_vac(' Sinovac')
sin_df2.describe()

#Combining the Sinovac data from three to one column
pre_sin_s = combine_series(sin_df2[2], sin_df2[1], ' Sinovac')
sin_s = combine_series(sin_df[0], pre_sin_s, 'Sinovac').str.lstrip(' ?')
sin_s.describe()

#Sinovac (284/4210) was administered to Brazil, Chile, China, Guatemala, Hong Kong, Indnesia, Malaysia, Northern Cyprus, Turkey, 
#Uruguay
# Out:
# count     4210
# unique       2
# top
# freq      3926
# dtype: object

# %% [markdown]
# ##### 2.6.5.1.10 Sputnik V Frequency<a id='2.6.5.1.10_Sputnik_V_Frequency'></a>

# %%
#'Sputnik V'
sput_df = get_vac('Sputnik V')
sput_df.describe()
sput_df2 = get_vac(' Sputnik V')
sput_df2.describe()

#Combining the SputnikV data from four to one column
c4n3_sput_s = combine_series(sput_df2[4], sput_df2[3], ' Sputnik V')
c2n1_sputs_s = combine_series(sput_df2[2], sput_df2[1], ' Sputnik V')
c4n3n2n1_sputs_s = combine_series(c4n3_sput_s, c2n1_sputs_s, ' Sputnik V')
sput_s = combine_series(sput_df[0], c4n3n2n1_sputs_s, 'Sputnik V').str.lstrip(' ?')
sput_s.describe()

#SputnikV (616/4210) was administered to Algeria, Argentina, Azerbaijan, Bahrain, Belarus, Bolivia, Hungary, Iran,  
#Kazakhstan, Mexico, Montenegro, Pakistan, Paraguay, Russia, San Marino, Serbia, United Arab Emirates, Venezuala
# Out:
# count     4210
# unique       2
# top
# freq      3594
# dtype: object

# %% [markdown]
# #### 2.6.5.2 Vaccines in Central America<a id='2.6.5.2_Vaccines_in_Central_America_Vaccinations'></a>

# %%
central_america_df = pd.concat([p_vaccine_data.loc[p_vaccine_data['country'] == 'El Salvador'],
                                 p_vaccine_data.loc[p_vaccine_data['country'] == 'Costa Rica'],
                                 p_vaccine_data.loc[p_vaccine_data['country'] == 'Guatemala'],
                                 p_vaccine_data.loc[p_vaccine_data['country'] == 'Panama']])
central_america_df.groupby('country')['vaccines'].unique()

#Belize, Honduras, Nicaragua not present in data set
# Out:
# country
# Costa Rica        [Pfizer/BioNTech]
# El Salvador    [Oxford/AstraZeneca]
# Guatemala                 [Sinovac]
# Panama            [Pfizer/BioNTech]
# Name: vaccines, dtype: object

# %% [markdown]
# Here is a list of vaccines that have been given to the Central American population, three of the countries that are not present for this continent can be accounted for in the total missing data for countries (3/77).

# %% [markdown]
# ### 2.6.6 Combining the Categorical Data<a id='2.6.6_Combining_the_Categorical_Data'></a>

# %%
#Creating a dictionary of series to ensure values are not altered
v_dict = {'Covaxin':c_df[0], 
          'EpiVacCorona':e_df[0], 
          'Johnson&Johnson':jnj_df[0], 
          'Moderna':m_df[0], 
          'Oxford/AstraZeneca':oxas_s,
          'Pfizer/BioNTech':pfiz_s,
          'Sinopharm/Beijing':sbe_s,
          'Sinopharm/Wuhan':swu_s,
          'Sinovac':sin_s,
          'Sputnik V':sput_s
         }

#Creating a dataframe with the complete vaccine series one column per vaccine
vtype_df = pd.DataFrame(data=v_dict)
vtype_df.head()
# Out:
#   Covaxin EpiVacCorona Johnson&Johnson Moderna Oxford/AstraZeneca  \
# 0
# 1
# 2
# 3
# 4
#
#    Pfizer/BioNTech Sinopharm/Beijing Sinopharm/Wuhan Sinovac Sputnik V
# 0  Pfizer/BioNTech
# 1  Pfizer/BioNTech
# 2  Pfizer/BioNTech
# 3  Pfizer/BioNTech
# 4  Pfizer/BioNTech

# %%
#Generating one dataframe with country/count/vaccine type by column 
vp_df = pd.concat([pop_v, vtype_df], axis=1)
vp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4210 entries, 0 to 4209
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4210 non-null   object
#  1   iso_code                             4210 non-null   object
#  2   date                                 4210 non-null   object
#  3   total_vaccinations                   4210 non-null   float64
#  4   people_fully_vaccinated              4210 non-null   float64
#  5   daily_vaccinations                   4210 non-null   float64
#  6   total_vaccinations_per_hundred       4210 non-null   float64
#  7   people_fully_vaccinated_per_hundred  4210 non-null   float64
#  8   vaccines                             4210 non-null   object
#  9   source_name                          4210 non-null   object
#  10  source_website                       4210 non-null   object
#  11  Covaxin                              4210 non-null   object
#  12  EpiVacCorona                         4210 non-null   object
#  13  Johnson&Johnson                      4210 non-null   object
#  14  Moderna                              4210 non-null   object
#  15  Oxford/AstraZeneca                   4210 non-null   object
#  16  Pfizer/BioNTech                      4210 non-null   object
#  17  Sinopharm/Beijing                    4210 non-null   object
#  18  Sinopharm/Wuhan                      4210 non-null   object
#  19  Sinovac                              4210 non-null   object
#  20  Sputnik V                            4210 non-null   object
# dtypes: float64(5), object(16)
# memory usage: 690.8+ KB

# %% [markdown]
# #### 2.6.6.1 Selecting Country Regions<a id='2.6.6.1_Selecting_Country_Regions'></a>

# %% [markdown]
# The country regions were selected because they had the most vaccine distribution, I believe this is a result of population prevalence.

# %%
def grab_countries(df, c_list):#c_list can be 1 or 0 to determine if a list or dataframe is returned

    can_df = df.loc[df['country'] == 'Canada']
    mex_df = df.loc[df['country'] == 'Mexico']
    ind_df = df.loc[df['country'] == 'Indonesia']
    bgd_df = df.loc[df['country'] == 'Bangladesh']
    mar_df = df.loc[df['country'] == 'Morocco']
    pol_df = df.loc[df['country'] == 'Poland']
    chl_df = df.loc[df['country'] == 'Chile']
    esp_df = df.loc[df['country'] == 'Spain']
    ity_df = df.loc[df['country'] == 'Italy']
    fra_df = df.loc[df['country'] == 'France']
    rus_df = df.loc[df['country'] == 'Russia']
    are_df = df.loc[df['country'] == 'United Arab Emirates']
    deu_df = df.loc[df['country'] == 'Germany']
    bra_df = df.loc[df['country'] == 'Brazil']
    isr_df = df.loc[df['country'] == 'Israel']
    tur_df = df.loc[df['country'] == 'Turkey']
    indi_df = df.loc[df['country'] == 'India']
    gbr_df = df.loc[df['country'] == 'United Kingdom']
    chn_df = df.loc[df['country'] == 'China']
    usa_df = df.loc[df['country'] == 'United States']

    df_list = [can_df, mex_df, ind_df, bgd_df, mar_df, pol_df, chl_df, esp_df, ity_df, fra_df, 
               rus_df, are_df, deu_df, bra_df, isr_df, tur_df, indi_df, gbr_df, chn_df, usa_df] 

    smaller_frame = pd.concat(df_list, ignore_index=True).reset_index().drop(columns='index')
    
    if c_list == 0:
        return smaller_frame
    if c_list == 1:
        return df_list
    

sorted_vdf = grab_countries(vp_df, 0)
sorted_vdf['date'] = pd.to_datetime(sorted_vdf['date'],format='%Y-%m-%d')

sorted_vdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1142 non-null   object
#  1   iso_code                             1142 non-null   object
#  2   date                                 1142 non-null   datetime64[ns]
#  3   total_vaccinations                   1142 non-null   float64
#  4   people_fully_vaccinated              1142 non-null   float64
#  5   daily_vaccinations                   1142 non-null   float64
#  6   total_vaccinations_per_hundred       1142 non-null   float64
#  7   people_fully_vaccinated_per_hundred  1142 non-null   float64
#  8   vaccines                             1142 non-null   object
#  9   source_name                          1142 non-null   object
#  10  source_website                       1142 non-null   object
#  11  Covaxin                              1142 non-null   object
#  12  EpiVacCorona                         1142 non-null   object
#  13  Johnson&Johnson                      1142 non-null   object
#  14  Moderna                              1142 non-null   object
#  15  Oxford/AstraZeneca                   1142 non-null   object
#  16  Pfizer/BioNTech                      1142 non-null   object
#  17  Sinopharm/Beijing                    1142 non-null   object
#  18  Sinopharm/Wuhan                      1142 non-null   object
#  19  Sinovac                              1142 non-null   object
#  20  Sputnik V                            1142 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(15)
# memory usage: 187.5+ KB

# %% [markdown]
# ### 2.6.7 Vaccine Entries by Country<a id='2.6.7_Vaccine_Entries_by_Country'></a>

# %%
def vaccine_count(vaccine_pair):
    num = 0
    for x in vaccine_pair:
        if len(x) != 0:
            num = num + 1
        else:
            num = 0
    return num


def country_vac_pair(c_list,v_list):
    vbc = []
    vacs_per_c = []
    for i in c_list:
        for j in v_list:
            num = vaccine_count(i[j])
            country = i.country.unique()
            vaccine = j
            vacs_per_c = [str(country).strip('[]'), vaccine, num] 
            vbc.append(vacs_per_c)
    
    return vbc


vac_list = ['Covaxin','EpiVacCorona','Johnson&Johnson','Moderna','Oxford/AstraZeneca', 
            'Pfizer/BioNTech', 'Sinopharm/Beijing','Sinopharm/Wuhan','Sinovac','Sputnik V']
country_list = grab_countries(sorted_vdf, 1)

vcount_df = pd.DataFrame(country_vac_pair(country_list, vac_list), columns = ['country', 'vaccine', 'count'])
vcount_df['country'] = vcount_df['country'].str.replace("'", '')
vcount_df.groupby('country')['count'].sum()
# Out:
# country
# Bangladesh               33
# Brazil                   88
# Canada                   96
# Chile                   132
# China                   168
# France                  189
# Germany                 192
# India                    88
# Indonesia                47
# Israel                  144
# Italy                   192
# Mexico                  201
# Morocco                  60
# Poland                  189
# Russia                  152
# Spain                   165
# Turkey                   47
# United Arab Emirates    275
# United Kingdom          154
# United States           142
# Name: count, dtype: int64

# %% [markdown]
# The totals above are a count of how many times each vaccine was listed for each country, at most 5 different kinds of vaccines were given to a single country. The graph below is a count of one out of many vaccines distributed to multiple countries.

# %%
#The numbers above and in the graph are relative to the number of times the vaccine was entered per country row. 
#They are not an indication of acutal vaccine counts
df = vcount_df.iloc[:140,:]
fig, ax = plt.subplots(figsize=(20, 10))
sns.scatterplot(x=df['country'], y=df['count'], hue='vaccine', data=df, markers=True, s=200, marker="o").set_title('Distribution of Vaccines by Country')
# Out:
# Text(0.5, 1.0, 'Distribution of Vaccines by Country')

# %% [markdown]
# This is a graph that does not include the US, UK, China, India, Turkey and Israel, from this subsection of countries paired with vaccines that the number of *entries* per vaccine (Sputnik V) was the highest for Russia. The most common vaccine is Pfizer which was distributed in Germany, France, Italy, Spain, Poland, and Canada. The next vaccine is Sinovac and it was given to Brazil, Chile and Indonesia. The least documented vaccine was Sinopharm/Beijing, found in Morocco. Of the total 10 vaccines only half can be found in this graph sample population (Sputnik V, Pfizer/BioNTech, Sinovac, Oxford/AstraZeneca, Sinopharm/Beijing). Some of the countries may have had more than the vaccines that have been identfied here.

# %% [markdown]
# ## 2.7 Load the COVID-19 Cases Data<a id='2.7_Load_the_COVID-19_Cases_Data'></a>

# %%
#the supplied CSV file is in the raw_data directory and was uploaded from kaggle: 
#https://www.kaggle.com/okwirjulius/covid19-cases-in-africa 
#Not all of the files that were downloaded will be used for this study, the following files were not included: 
#covid19_oceania.csv, covid19_others.csv, covid19_world.csv, and covid19_tests.csv

# get data file names
path =r'..\raw_data\covid_case_files'
filenames = glob.glob(path + "/*.csv")
def concat_dfs(filnames):
    dfs = []
    for filename in filenames:
        dfs.append(pd.read_csv(filename))
    la_frame = pd.concat(dfs, ignore_index=True)
    
    return la_frame

# Concatenate all data into one DataFrame
big_frame = concat_dfs(filenames)

#Update column names 
rec_cases = big_frame.rename(columns={'ObservationDate':'date','Country_Region':'country'})
rec_cases = rec_cases.drop(columns=['Province_State'])
rec_cases.columns = rec_cases.columns.str.lower()
rec_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038272 entries, 0 to 1038271
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   date       1038272 non-null  object
#  1   country    1038272 non-null  object
#  2   confirmed  1038272 non-null  int64
#  3   deaths     1038271 non-null  float64
#  4   recovered  1038270 non-null  float64
#  5   active     1037789 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 47.5+ MB

# %% [markdown]
# ## 2.8 Explore the Data<a id='2.8_Explore_the_Data'></a>

# %%
#Set country as the index
r_case = rec_cases.set_index('country')

#rename us to United States
rc = r_case.rename(index={'US':'United States'})
cases = rc.reset_index()
cases[cases['country'] == 'United States'].tail()
# Out:
#               country        date  confirmed  deaths  recovered  active
# 999815  United States  2020-12-31       2138     4.0        0.0  2134.0
# 999816  United States  2020-12-31       1558     7.0        0.0  1551.0
# 999817  United States  2020-12-31          0     0.0        0.0     0.0
# 999818  United States  2020-12-31        781    19.0        0.0   762.0
# 999819  United States  2020-12-31        476     2.0        0.0   474.0

# %%
cos = cases.set_index('date')
covcs = cos.reset_index()
covcs.iloc[80017:80027]
# Out:
#              date      country  confirmed  deaths  recovered   active
# 80017  2020-09-19       Sweden       1241    73.0        0.0   1168.0
# 80018  2020-09-19       Sweden        905    31.0        0.0    874.0
# 80019  2020-09-19       Sweden       1881   136.0        0.0   1745.0
# 80020  2020-09-19       Sweden       2854   183.0        0.0   2671.0
# 80021  2020-09-19       Sweden      19514   860.0        0.0  18654.0
# 80022  2020-09-19  Switzerland      49283  2045.0    40500.0   6738.0
# 80023  2020-09-19      Ukraine       2983    48.0     1345.0   1590.0
# 80024  2020-09-19      Ukraine       3188    46.0      738.0   2404.0
# 80025  2020-09-19      Ukraine      12917   329.0     7514.0   5074.0
# 80026  2020-09-19      Ukraine       3573    47.0     2400.0   1126.0

# %% [markdown]
# ### 2.8.1 Numerical Data<a id='2.8.1_Numerical_Data'></a>

# %% [markdown]
# #### 2.8.1.1 Missing COVID-19 Values<a id='2.8.1.1_Missing_COVID-19_Values'></a>

# %%
#Find instances of null values in the columns
missing_cases = covcs[['deaths','recovered','active']].isnull().sum()
missing_cases
# Out:
# deaths         1
# recovered      2
# active       483
# dtype: int64

# %% [markdown]
# There are more than a million rows of data in the COVID-19 cases dataset. There are a few null values in deaths and recovered and 483 null values in the active cases column. To better understand the missing COVID-19 data, the number of countries can be compared to the the total number of countries in the world, before isolating the 20 countries of interest.

# %%
#Find null values in each row
miss_data = covcs.isnull()
md = miss_data.any(axis=1)
md_rows = covcs[md]

#Group the rows including null values by country and sum the values
md_rows.groupby('country').agg('sum')
# Out:
#                confirmed  deaths  recovered  active
# country
# Canada                 0   180.0        0.0     0.0
# Chile               5617   114.0     5617.0     0.0
# Colombia               0     0.0        3.0     0.0
# Japan               5373    21.0     5379.0     0.0
# Spain               3464    70.0     3418.0     0.0
# Suriname            5333   117.0     5217.0     0.0
# United States          3   361.0        0.0  -226.0

# %% [markdown]
# There is *missing* data for the countries that will be exported. Also, there is a weird negative value for active. There cannot possibly be less active infections than zero. This poses a bigger question - for the data as a whole - a more in depth look at the negative values for any of the columns in covid case data or the vaccine data will be conducted. We can determine if there are other rows in both sets.

# %%
#Select the rows with the null value
miss_rc = md_rows['recovered'].isnull()
miss_recovered = md_rows[miss_rc]
miss_recovered['recovered']
# Out:
# 830691   NaN
# 833979   NaN
# Name: recovered, dtype: float64

# %% [markdown]
# ## Missing Data
#
#
# <table style="width:100%">
# <table align= "left">
# <tr>
# <th>country</th>
# <th>active</th>
# <th>deaths</th>
# <th>recovered</th>
# </tr>
#
# <tr>
# <td>Canada</td>
# <td>180</td>
# <td>0</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>Chile</td>
# <td>114</td>
# <td>0</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>Colombia</td>
# <td>3</td>
# <td>1</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>Japan</td>
# <td>27</td>
# <td>0</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>Spain</td>
# <td>24</td>
# <td>0</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>Suriname</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# </tr>
#
# <tr>
# <td>US</td>
# <td>134</td>
# <td>0</td>
# <td>2</td>
# </tr>
# </table>

# %% [markdown]
# ### 2.8.1.2 Negative Vaccine Data<a id='2.8.1.2_Negative_Vaccine_Data'></a>

# %%
#Sum missing values for daily vaccinations
neg_vvalues = vaccine_data['daily_vaccinations'] < 0
neg_vvalues.sum()
# Out:
# 0

# %% [markdown]
# ### 2.8.1.3 Negative COVID-19 Data<a id='2.8.1.3_Negative_COVID-19_Data'></a>

# %%
#Find rows of negative values
def get_negative(df, col):
    neg_num = df[col] < 0
    less_pos = neg_num.any(axis=1)
    lp = df[less_pos]
    return lp


#Select confirmed values that are negative
get_negative(covcs, ['confirmed'])
# Out:
#                date   country  confirmed  deaths  recovered    active
# 1028462  2020-11-02  Colombia    -302844     0.0        0.0 -302844.0

# %%
#Select death values that are negative
get_negative(covcs, ['deaths'])
# Out:
#                date   country  confirmed  deaths  recovered   active
# 1022230  2020-09-24  Colombia          0  -178.0   -12684.0  12862.0
# 1027150  2020-10-25  Colombia          0  -154.0    -8072.0   8226.0

# %%
#Select recovered values that are negative
get_negative(covcs, ['recovered'])
# Out:
#                date   country  confirmed  deaths  recovered    active
# 1022230  2020-09-24  Colombia          0  -178.0   -12684.0   12862.0
# 1027150  2020-10-25  Colombia          0  -154.0    -8072.0    8226.0
# 1027970  2020-10-30  Colombia          0   505.0  -854405.0  853900.0

# %% [markdown]
# The indices listed above for confirmed, deaths, recovered are all in the Colombian data set. This could be an incorrect entry or an attempt to correct the number of confirmed, deaths, and recovered cases. If the number is incorrect then this will definitely skew the data. However, the Colombian set will not be included in countries to be analyzed, and this is a moot point.

# %%
active_differences = get_negative(covcs, ['active'])
active_differences.country.unique()
# Out:
# array(['Japan', 'India', 'Timor-Leste', 'Spain', 'United Kingdom',
#        'Russia', 'Germany', 'Luxembourg', 'Iceland', 'Belgium',
#        'United States', 'Canada', 'Brazil', 'Chile', 'Peru', 'Colombia',
#        'Mexico', 'Suriname'], dtype=object)

# %% [markdown]
# There are quite a few countries of interest that have negative values for active infections. Below are the definitions for each of the columns.
#
# * Confirmed: the number of COVID-19 confirmed cases
# * Deaths: the number of deaths from COVID-19
# * Recovered: the number of recovered cases
# * Active: the number of people still infected with COVID-19
# * **Note**: Active = Confirmed - (Deaths + Recovered)
#
# The active data is confirmed infections minus death plus recovered. Understanding the numbers as they are entered on a daily bases, the equation does not have to result in a positive value. If there are more deaths and recovered for any given day than the confirmed cases this will result in a negative number. The closest we could come to verifying the accuracy of these entries would be to compare the total to populations for each country of interest. The amount of confirmed cases should not be greater than the population of that country. To ensure that all of the active data is calculated and gives a value, either negative or positive, the active number will be re-calculated and verified.

# %% [markdown]
# ### 2.8.1.4 Calculation of Active Cases<a id='2.8.1.4_Calculation_of_Active_Cases'></a>

# %%
dere = covcs['deaths'].add(covcs['recovered']) #deaths + recovered 
covcs['active'] = covcs['confirmed'].sub(dere) #confirmed - (deaths + recovered)
covcs.iloc[40146:40153]
# Out:
#              date  country  confirmed  deaths  recovered   active
# 40146  2020-12-08    China       1295     1.0     1288.0      6.0
# 40147  2020-12-08   Cyprus      13286    68.0     2057.0  11161.0
# 40148  2020-12-08  Georgia     169649  1576.0   141392.0  26681.0
# 40149  2020-12-08    India       4778    61.0     4647.0     70.0
# 40150  2020-12-08    India     872839  7042.0   860368.0   5429.0
# 40151  2020-12-08    India      16437    55.0    15690.0    692.0
# 40152  2020-12-08    India     214019   997.0   209447.0   3575.0

# %%
#Verify no null values in active column
miss_act = covcs.isnull()
ma = miss_act.any(axis=1)
ma_rows = covcs[ma]
ma_rows
# Out:
#                date        country  confirmed  deaths  recovered  active
# 830691   2020-11-10  United States          0   113.0        NaN     NaN
# 833979   2020-11-11  United States          0   113.0        NaN     NaN
# 1027642  2020-10-28       Colombia          0     NaN        0.0     NaN

# %% [markdown]
# Now there are 3 rows of missing values instead of 483.

# %%
#Entering 0 value for null, US recovered, active first row
covcs.iloc[830691,5] = -113
covcs.iloc[830691,4] = 0

#Entering 0 value for null, US recovered, active second row
covcs.iloc[833979,5] = -113
covcs.iloc[833979,4] = 0

#Entering 0 value for null, Colombia deaths, active
covcs.iloc[1027642,3] = 0
covcs.iloc[1027642,5] = 0


bf_change = pd.DataFrame(data=covcs, index=[830691, 833979, 1027642])
bf_change
# Out:
#                date        country  confirmed  deaths  recovered  active
# 830691   2020-11-10  United States          0   113.0        0.0  -113.0
# 833979   2020-11-11  United States          0   113.0        0.0  -113.0
# 1027642  2020-10-28       Colombia          0     0.0        0.0     0.0

# %% [markdown]
# ### 2.8.1.5 Numbers Between 1 and 0<a id='2.8.1.5_Numbers_Between_1_and_0'></a>

# %%
# Find series between 1 and 0
frac_co = covcs['confirmed'].between(0, 1, inclusive=False) 
  
# returning dataframe with confirmed between above values 
len(covcs[frac_co])
# Out:
# 0

# %%
# Find series between 1 and 0
frac_ac = covcs['active'].between(0, 1, inclusive=False) 
  
# returning dataframe with confirmed between above values 
len(covcs[frac_ac])
# Out:
# 0

# %%
# Find series between 1 and 0
frac_re = covcs['recovered'].between(0, 1, inclusive=False) 
  
# returning dataframe with confirmed between above values 
len(covcs[frac_re])
# Out:
# 0

# %%
#Verify no null values in active column
third_null = covcs.isnull()
tn = third_null.any(axis=1)
tn_rows = covcs[tn]
len(tn_rows)
# Out:
# 0

# %%
covcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038272 entries, 0 to 1038271
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   date       1038272 non-null  object
#  1   country    1038272 non-null  object
#  2   confirmed  1038272 non-null  int64
#  3   deaths     1038272 non-null  float64
#  4   recovered  1038272 non-null  float64
#  5   active     1038272 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 47.5+ MB

# %% [markdown]
# ### 2.8.2 Categorical Data<a id='2.8.2_Categorical_Data'></a>

# %% [markdown]
# ### 2.8.2.1 Countries in COVID-19 Data<a id='2.8.2.1_Countries_in_COVID-19_Data'></a>

# %%
c_in_case_data = pd.Series(covcs.country.unique())
c_in_case_data.iloc[:50]
# Out:
# 0                    China
# 1                Hong Kong
# 2                    Macau
# 3                   Taiwan
# 4                    Japan
# 5                 Thailand
# 6              South Korea
# 7                Singapore
# 8              Philippines
# 9                 Malaysia
# 10                 Vietnam
# 11                   Nepal
# 12                Cambodia
# 13               Sri Lanka
# 14    United Arab Emirates
# 15                   India
# 16                    Iran
# 17                  Israel
# 18                 Lebanon
# 19                    Iraq
# 20                    Oman
# 21             Afghanistan
# 22                 Bahrain
# 23                  Kuwait
# 24                Pakistan
# 25                 Georgia
# 26              Azerbaijan
# 27                   Qatar
# 28                 Armenia
# 29               Indonesia
# 30            Saudi Arabia
# 31                  Jordan
# 32      West Bank and Gaza
# 33                  Bhutan
# 34                Maldives
# 35              Bangladesh
# 36                  Cyprus
# 37                  Brunei
# 38                Mongolia
# 39                  Turkey
# 40              Kazakhstan
# 41              Uzbekistan
# 42              Kyrgyzstan
# 43             Timor-Leste
# 44                   Syria
# 45                    Laos
# 46                   Burma
# 47                   Yemen
# 48              Tajikistan
# 49                  France
# dtype: object

# %%
c_in_case_data.iloc[50:100]
# Out:
# 50                   Germany
# 51                   Finland
# 52                     Italy
# 53            United Kingdom
# 54                    Russia
# 55                    Sweden
# 56                     Spain
# 57                   Belgium
# 58                   Austria
# 59                   Croatia
# 60               Switzerland
# 61                    Greece
# 62           North Macedonia
# 63                    Norway
# 64                   Romania
# 65                   Denmark
# 66                   Estonia
# 67               Netherlands
# 68                San Marino
# 69                   Belarus
# 70                   Iceland
# 71                 Lithuania
# 72                   Ireland
# 73                Luxembourg
# 74                    Monaco
# 75                   Czechia
# 76                  Portugal
# 77                   Andorra
# 78                    Latvia
# 79                   Ukraine
# 80                   Hungary
# 81             Liechtenstein
# 82                    Poland
# 83    Bosnia and Herzegovina
# 84                  Slovenia
# 85                    Serbia
# 86                  Slovakia
# 87              Vatican City
# 88                     Malta
# 89                  Bulgaria
# 90                   Moldova
# 91                   Albania
# 92                  Holy See
# 93                  Guernsey
# 94                    Jersey
# 95                Montenegro
# 96             United States
# 97                    Canada
# 98                    Mexico
# 99                    Brazil
# dtype: object

# %%
c_in_case_data.iloc[100:]
# Out:
# 100                            Colombia
# 101                             Ecuador
# 102                  Dominican Republic
# 103                           Argentina
# 104                               Chile
# 105                    Saint Barthelemy
# 106                          Costa Rica
# 107                                Peru
# 108                       French Guiana
# 109                          Martinique
# 110                            Paraguay
# 111                              Panama
# 112                             Bolivia
# 113                            Honduras
# 114                             Jamaica
# 115                                Cuba
# 116                          Guadeloupe
# 117                 Antigua and Barbuda
# 118                              Guyana
# 119                             Uruguay
# 120                 Trinidad and Tobago
# 121                           Venezuela
# 122                           Guatemala
# 123                         Saint Lucia
# 124    Saint Vincent and the Grenadines
# 125                            Suriname
# 126                             Bahamas
# 127                            Barbados
# 128                         El Salvador
# 129                           Nicaragua
# 130                               Haiti
# 131                            Dominica
# 132                             Grenada
# 133                              Belize
# 134               Saint Kitts and Nevis
# dtype: object

# %% [markdown]
# There are 135 different rows for the countries and that is not including Africa. The African dataset had to be handled a bit differently because the column names were different than the files for Asia, Europe, North America, and South America.

# %%
#Load dataframe and update column names 
africa_df = pd.read_csv('../raw_data/covid19_africa.csv')
africa_df = africa_df.rename(columns={'ObservationDate':'date'}).drop(columns=['Region'])
africa_df.columns = africa_df.columns.str.lower()
africa_df.head()
# Out:
#          date      country  confirmed  deaths  recovered  active
# 0  2020-01-27  Ivory Coast          1       0          0       1
# 1  2020-02-14        Egypt          1       0          0       1
# 2  2020-02-15        Egypt          1       0          0       1
# 3  2020-02-16        Egypt          1       0          0       1
# 4  2020-02-17        Egypt          1       0          0       1

# %%
af_case_data = pd.Series(africa_df.country.unique())
af_case_data
# Out:
# 0                  Ivory Coast
# 1                        Egypt
# 2                      Algeria
# 3                      Nigeria
# 4                      Morocco
# 5                      Senegal
# 6                      Tunisia
# 7                 South Africa
# 8                     Cameroon
# 9                         Togo
# 10                Burkina Faso
# 11            Congo (Kinshasa)
# 12                    Ethiopia
# 13                       Sudan
# 14                      Guinea
# 15                       Kenya
# 16                       Ghana
# 17                     Namibia
# 18                  Seychelles
# 19                    Eswatini
# 20                       Gabon
# 21                  Mauritania
# 22                      Rwanda
# 23    Central African Republic
# 24         Congo (Brazzaville)
# 25           Equatorial Guinea
# 26                       Benin
# 27                     Liberia
# 28                     Somalia
# 29                    Tanzania
# 30                   Mauritius
# 31                      Zambia
# 32                    Djibouti
# 33                        Chad
# 34                  Madagascar
# 35                      Angola
# 36                  Cabo Verde
# 37                       Niger
# 38                    Zimbabwe
# 39                     Eritrea
# 40                      Uganda
# 41                      Gambia
# 42                  Mozambique
# 43                       Libya
# 44               Guinea-Bissau
# 45                        Mali
# 46                    Botswana
# 47                     Burundi
# 48                Sierra Leone
# 49                      Malawi
# 50                 South Sudan
# 51       Sao Tome and Principe
# 52                     Comoros
# 53                     Lesotho
# dtype: object

# %%
the_case = ['confirmed','deaths','recovered','active']
af_acru = get_negative(africa_df, the_case)
af_acru
# Out:
#             date country  confirmed  deaths  recovered  active
# 6758  2020-07-20  Uganda       1069       0       1071      -2

# %% [markdown]
# There are 54 countries in the African data, that is all the countries in Africa! The total number of countries is 189, this is extremely close to 100% representation of the entire world population. There is only a -2 difference that can be found for active COVID-19 infections.

# %%
# Concatonating africa data with the other countries
covid_cases = pd.concat([africa_df, covcs], axis=0)
covid_cases.describe()
# Out:
#           confirmed        deaths     recovered        active
# count  1.053727e+06  1.053727e+06  1.053727e+06  1.053727e+06
# mean   7.140784e+03  2.088023e+02  4.434816e+03  2.497163e+03
# std    4.865572e+04  1.538404e+03  5.507252e+04  4.773747e+04
# min   -3.028440e+05 -1.780000e+02 -8.544050e+05 -6.399531e+06
# 25%    4.100000e+01  0.000000e+00  0.000000e+00  3.200000e+01
# 50%    3.020000e+02  5.000000e+00  0.000000e+00  2.490000e+02
# 75%    1.589000e+03  3.300000e+01  0.000000e+00  1.206000e+03
# max    2.616902e+06  6.426700e+04  6.399531e+06  2.382209e+06

# %% [markdown]
# The entire world had an average confirmed COVID-19 cases of 7140 and a standard deviation of 48655, the average deaths due to COVID-19 was 208 with a standard deviation of 1538. The average number of people that recovered from COVID-19 was 4434 and there was a standard deviation of 5507. The average active COVID-19 cases was 249 and had an standard deviation of 4777. This happened all in the year 2020.

# %%
#Updating the date datatype
covcs['date'] = pd.to_datetime(covcs['date'],format='%Y-%m-%d')

#Grouping by the date by days and including the countries
grouped_cases = covcs.groupby([covcs['date'].dt.date, 'country']).agg('sum')
grouped_cases = grouped_cases.sort_values(['country','date']).reset_index()
grouped_cases['date'] = pd.to_datetime(grouped_cases['date'],format='%Y-%m-%d')
grouped_cases.iloc[630:640]
# Out:
#           date  country  confirmed  deaths  recovered  active
# 630 2020-04-27  Andorra        743    40.0      385.0   318.0
# 631 2020-04-28  Andorra        743    41.0      398.0   304.0
# 632 2020-04-29  Andorra        743    42.0      423.0   278.0
# 633 2020-04-30  Andorra        745    42.0      468.0   235.0
# 634 2020-05-01  Andorra        745    43.0      468.0   234.0
# 635 2020-05-02  Andorra        747    44.0      472.0   231.0
# 636 2020-05-03  Andorra        748    45.0      493.0   210.0
# 637 2020-05-04  Andorra        750    45.0      499.0   206.0
# 638 2020-05-05  Andorra        751    46.0      514.0   191.0
# 639 2020-05-06  Andorra        751    46.0      521.0   184.0

# %% [markdown]
# ### 2.8.3 World COVID-19 Distribution<a id='2.8.3_World_COVID-19_Distribution'></a>

# %%
grouped_cases.hist(figsize=(15,10));

# %% [markdown]
# There are values that are clustered around the low end. In the beginning of 2020 COVID-19 was unknown and unseen, the identity of the disease was first found in Wuhan, and the etiology was later seen in other regions, knowledge about the deadly virus spread just as quickly as the virus. The classification of the disease changed from being an endemic to a pandemic, early in 2020. These values here are in countries that did not experience exposure until later in the year.

# %%
#Grouping the data by month and year
data_by_mo = grouped_cases.groupby([grouped_cases.date.dt.year, 
                                    grouped_cases.date.dt.month, 
                                    'country'])[['confirmed','deaths','recovered','active']].sum()

#Label the multi-index column names with year and month 
data_by_mo.index = data_by_mo.index.set_names(['year','month'], level=[0,1])
c_cases = data_by_mo.reset_index()
c_cases[c_cases['month'] == 10].iloc[5:10]
# Out:
#      year  month     country  confirmed   deaths  recovered    active
# 992  2020     10     Armenia    2012415  33744.0  1490885.0  487786.0
# 993  2020     10     Austria    2039236  28062.0  1521700.0  489474.0
# 994  2020     10  Azerbaijan    1403733  19697.0  1242714.0  141322.0
# 995  2020     10     Bahamas     170339   3612.0   100515.0   66212.0
# 996  2020     10     Bahrain    2388821   8985.0  2262718.0  117118.0

# %%
#Macau, Taiwan, Philipeans, Vietnam, Laos
mac_cases = covcs[covcs['country'] == 'Macau']
hk_cases = covcs[covcs['country'] == 'Hong Kong']
phi_cases = covcs[covcs['country'] == 'Philippines']
vie_cases = covcs[covcs['country'] == 'Vietnam']
lao_cases = covcs[covcs['country'] == 'Laos']
so_asia = pd.concat([mac_cases, hk_cases, phi_cases, vie_cases, lao_cases])
s_asia = so_asia.sort_values('date')
s_asia.shape
# Out:
# (1640, 6)

# %% [markdown]
# ### 2.8.3.1 Coastal Asian Active COVID-19 Cases<a id='2.8.3.1_Coastal_Asian_Active_COVID-19_Cases'></a>

# %%
#Graphing the Asian data
f, ax = plt.subplots(figsize=(10, 10))

ax.set(xlabel="Date",
       ylabel="Active",
       title="Active COVID-19 Cases\nDEC2020 - JAN2021")

sns.despine(f, left=True, bottom=True)
sasia = ['Macau', 'Hong Kong', 'Vietnam', 'Philippines', 'Laos']
sns.scatterplot(x="date", y="active",
                hue="country", size="active",
                palette="deep",
                hue_order=sasia,
                sizes=(3, 8), linewidth=0,
                data=s_asia, ax=ax)
# Out:
# <AxesSubplot:title={'center':'Active COVID-19 Cases\nDEC2020 - JAN2021'}, xlabel='Date', ylabel='Active'>

# %% [markdown]
# A selection of coastal countries in Asia shows that the highest active cases occurred in the Philippines. The peak of the data is a little above 80000 for active cases. That is a huge amount of people needing medical assistance!

# %%
#Concatonating africa data with the other countries 
cc_df = grab_countries(covid_cases, 0)

#Updating the date datatype
cc_df['date'] = pd.to_datetime(cc_df['date'],format='%Y-%m-%d')

#Checking for countries
cc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967749 entries, 0 to 967748
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       967749 non-null  datetime64[ns]
#  1   country    967749 non-null  object
#  2   confirmed  967749 non-null  int64
#  3   deaths     967749 non-null  float64
#  4   recovered  967749 non-null  float64
#  5   active     967749 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 44.3+ MB

# %%
cc_df.country.unique()
# Out:
# array(['Canada', 'Mexico', 'Indonesia', 'Bangladesh', 'Morocco', 'Poland',
#        'Chile', 'Spain', 'Italy', 'France', 'Russia',
#        'United Arab Emirates', 'Germany', 'Brazil', 'Israel', 'Turkey',
#        'India', 'United Kingdom', 'China', 'United States'], dtype=object)

# %%
cc_df.sort_values('date')
collect_end_date = cc_df.date.max()
collect_start_date = cc_df.date.min()

print('start date:', collect_start_date, '|    end date:', collect_end_date)
# Out:
# start date: 2020-01-22 00:00:00 |    end date: 2020-12-31 00:00:00

# %% [markdown]
# There is very little overlapping time-dependent data given for the vaccine data (1 month in 2020, 3 months in 2021) and the COVID-19 case data (all of 2020), the overlapping data happened on December 14th 2020 to December 31st 2020. There will be four cleaned files generated including data for 20 countries to conduct further analysis and identify predictive models: the first set is vaccination data(two files), the second set is COVID-19 case data(one file) and last is population data(one file) for the 20 countries by continent:
#
#     Africa: *Morocco
#     Asia: *Indonesia, *Bangladesh, *United Arab Emirates, *Israel, *Turkey, *India, *China, *Russia
#     Europe: *Poland, *Spain, *Italy, *France, *United Kingdom, *Germany
#     North America: *United States, *Canada, *Mexico
#     South America: *Chile, *Brazil

# %% [markdown]
# ## 2.9 Load the World Population Data<a id='2.9_Load_the_World_Population_Data'></a>

# %%
#Loading world population data
world_p = pd.read_csv('../raw_data/World_population(2020).csv')
world_p = world_p.rename(columns={'Country (or dependency)':'country'})
world_p.head()
# Out:
#           country  Population (2020) Yearly Change  Net Change  \
# 0     Afghanistan           38928346        2.33 %      886592
# 1         Albania            2877797       -0.11 %       -3120
# 2         Algeria           43851044        1.85 %      797990
# 3  American Samoa              55191       -0.22 %        -121
# 4         Andorra              77265        0.16 %         123
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0               60           652860        -62920.0        4.6       18
# 1              105            27400        -14000.0        1.6       36
# 2               18          2381740        -10000.0        3.1       29
# 3              276              200             NaN       N.A.     N.A.
# 4              164              470             NaN       N.A.     N.A.
#
#   Urban Pop % World Share
# 0        25 %      0.50 %
# 1        63 %      0.04 %
# 2        73 %      0.56 %
# 3        88 %      0.00 %
# 4        88 %      0.00 %

# %%
world_subset = grab_countries(world_p, 0).sort_values('Population (2020)', ascending=False)
world_subset
# Out:
#                  country  Population (2020) Yearly Change  Net Change  \
# 18                 China         1439323776        0.39 %     5540090
# 16                 India         1380004385        0.99 %    13586631
# 19         United States          331002651        0.59 %     1937734
# 2              Indonesia          273523615        1.07 %     2898047
# 13                Brazil          212559417        0.72 %     1509890
# 3             Bangladesh          164689383        1.01 %     1643222
# 10                Russia          145934462        0.04 %       62206
# 1                 Mexico          128932753        1.06 %     1357224
# 15                Turkey           84339067        1.09 %      909452
# 12               Germany           83783942        0.32 %      266897
# 17        United Kingdom           67886011        0.53 %      355839
# 9                 France           65273511        0.22 %      143783
# 8                  Italy           60461826       -0.15 %      -88249
# 7                  Spain           46754778        0.04 %       18002
# 5                 Poland           37846611       -0.11 %      -41157
# 0                 Canada           37742154        0.89 %      331107
# 4                Morocco           36910560        1.20 %      438791
# 6                  Chile           19116201        0.87 %      164163
# 11  United Arab Emirates            9890402        1.23 %      119873
# 14                Israel            8655535        1.60 %      136158
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 18              153          9388211       -348399.0        1.7       38
# 16              464          2973190       -532687.0        2.2       28
# 19               36          9147420        954806.0        1.8       38
# 2               151          1811570        -98955.0        2.3       30
# 13               25          8358140         21200.0        1.7       33
# 3              1265           130170       -369501.0        2.1       28
# 10                9         16376870        182456.0        1.8       40
# 1                66          1943950        -60000.0        2.1       29
# 15              110           769630        283922.0        2.1       32
# 12              240           348560        543822.0        1.6       46
# 17              281           241930        260650.0        1.8       40
# 9               119           547557         36527.0        1.9       42
# 8               206           294140        148943.0        1.3       47
# 7                94           498800         40000.0        1.3       45
# 5               124           306230        -29395.0        1.4       42
# 0                 4          9093510        242032.0        1.5       41
# 4                83           446300        -51419.0        2.4       30
# 6                26           743532        111708.0        1.7       35
# 11              118            83600         40000.0        1.4       33
# 14              400            21640         10000.0        3.0       30
#
#    Urban Pop % World Share
# 18        61 %     18.47 %
# 16        35 %     17.70 %
# 19        83 %      4.25 %
# 2         56 %      3.51 %
# 13        88 %      2.73 %
# 3         39 %      2.11 %
# 10        74 %      1.87 %
# 1         84 %      1.65 %
# 15        76 %      1.08 %
# 12        76 %      1.07 %
# 17        83 %      0.87 %
# 9         82 %      0.84 %
# 8         69 %      0.78 %
# 7         80 %      0.60 %
# 5         60 %      0.49 %
# 0         81 %      0.48 %
# 4         64 %      0.47 %
# 6         85 %      0.25 %
# 11        86 %      0.13 %
# 14        93 %      0.11 %

# %% [markdown]
# ## 2.10 Normalizing the Data<a id='2.10_Normalizing_the_Data'></a>

# %%
from sklearn.preprocessing import PowerTransformer

log = PowerTransformer()

#Converting confirmed cases
log.fit(cc_df[['confirmed']])
cc_df['log_converted_confirmed'] = log.transform(cc_df[['confirmed']])

# %%
#Converting death cases
log.fit(cc_df[['deaths']])
cc_df['log_converted_deaths'] = log.transform(cc_df[['deaths']])

# %%
#Converting recovered cases
log.fit(cc_df[['recovered']])
cc_df['log_converted_recovered'] = log.transform(cc_df[['recovered']])

# %%
#Converting active cases
log.fit(cc_df[['active']])
cc_df['log_converted_active'] = log.transform(cc_df[['active']])

# %%
world_subset.head()
# Out:
#           country  Population (2020) Yearly Change  Net Change  \
# 18          China         1439323776        0.39 %     5540090
# 16          India         1380004385        0.99 %    13586631
# 19  United States          331002651        0.59 %     1937734
# 2       Indonesia          273523615        1.07 %     2898047
# 13         Brazil          212559417        0.72 %     1509890
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 18              153          9388211       -348399.0        1.7       38
# 16              464          2973190       -532687.0        2.2       28
# 19               36          9147420        954806.0        1.8       38
# 2               151          1811570        -98955.0        2.3       30
# 13               25          8358140         21200.0        1.7       33
#
#    Urban Pop % World Share
# 18        61 %     18.47 %
# 16        35 %     17.70 %
# 19        83 %      4.25 %
# 2         56 %      3.51 %
# 13        88 %      2.73 %

# %%
sorted_vdf.country.unique()
# Out:
# array(['Canada', 'Mexico', 'Indonesia', 'Bangladesh', 'Morocco', 'Poland',
#        'Chile', 'Spain', 'Italy', 'France', 'Russia',
#        'United Arab Emirates', 'Germany', 'Brazil', 'Israel', 'Turkey',
#        'India', 'United Kingdom', 'China', 'United States'], dtype=object)

# %%
vc_list = ['Canada', 'Mexico', 'Indonesia', 'Bangladesh', 'Morocco', 'Poland',
       'Chile', 'Spain', 'Italy', 'France', 'Russia',
       'United Arab Emirates', 'Germany', 'Brazil', 'Israel', 'Turkey',
       'India', 'United Kingdom', 'China', 'United States']

# %%
def vac_ratio(country):
    
    demo = world_subset[world_subset['country'] == country]
    pop = int(demo['Population (2020)'])
    
    c = sorted_vdf[sorted_vdf['country'] == country]
    tot_vac_series = c['total_vaccinations']
    
    per_vac = tot_vac_series / pop
    
    return per_vac

# %%
vac_rat_series = []

for i in vc_list:
    vac_rat_by_c = vac_ratio(i)
    vac_rat_series.append(vac_rat_by_c)
    vc_series = pd.concat(vac_rat_series)

# %%
sorted_vdf['vaccine_ratio'] = vc_series

# %% [markdown]
# ## 2.11 Convert Datatypes<a id='2.11_Convert_Data_Types'></a>

# %%
#convert vaccine data frame to numeric columns to int data types
sorted_vdf['total_vaccinations'] = sorted_vdf['total_vaccinations'].astype('int64', copy=False)
sorted_vdf['people_fully_vaccinated'] = sorted_vdf['people_fully_vaccinated'].astype('int64', copy=False)
sorted_vdf['daily_vaccinations'] = sorted_vdf['daily_vaccinations'].astype('int64', copy=False)
sorted_vdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1142 non-null   object
#  1   iso_code                             1142 non-null   object
#  2   date                                 1142 non-null   datetime64[ns]
#  3   total_vaccinations                   1142 non-null   int64
#  4   people_fully_vaccinated              1142 non-null   int64
#  5   daily_vaccinations                   1142 non-null   int64
#  6   total_vaccinations_per_hundred       1142 non-null   float64
#  7   people_fully_vaccinated_per_hundred  1142 non-null   float64
#  8   vaccines                             1142 non-null   object
#  9   source_name                          1142 non-null   object
#  10  source_website                       1142 non-null   object
#  11  Covaxin                              1142 non-null   object
#  12  EpiVacCorona                         1142 non-null   object
#  13  Johnson&Johnson                      1142 non-null   object
#  14  Moderna                              1142 non-null   object
#  15  Oxford/AstraZeneca                   1142 non-null   object
#  16  Pfizer/BioNTech                      1142 non-null   object
#  17  Sinopharm/Beijing                    1142 non-null   object
#  18  Sinopharm/Wuhan                      1142 non-null   object
#  19  Sinovac                              1142 non-null   object
#  20  Sputnik V                            1142 non-null   object
#  21  vaccine_ratio                        1142 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(15)
# memory usage: 196.4+ KB

# %% [markdown]
# ## 2.12 Save data<a id='2.12_Save_data'></a>

# %%
# save the data to a new csv file
datapath = '../data'
save_file(sorted_vdf, 'vaccine_data_cleaned.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)y
# Writing file.  "../data\vaccine_data_cleaned.csv"

# %%
# save the vaccine_summary separately.
save_file(vcount_df, 'vaccine_summary.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)y
# Writing file.  "../data\vaccine_summary.csv"

# %%
# save the vaccine_summary separately.
save_file(cc_df, 'covid_cases_cleaned.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)y
# Writing file.  "../data\covid_cases_cleaned.csv"

# %%
# save the world_subset separately.
save_file(world_subset, 'world_subset.csv', datapath)
# Out:
# Writing file.  "../data\world_subset.csv"

# %% [markdown]
# ## 2.13 Summary<a id='2.12_Summary'></a>

# %% [markdown]
# Unfortunately, we cannot derive the individual vaccine count based on daily vaccinations for *all* countries. We can identify countries where only one vaccination was given and this would be an accurate representation for the vaccine distribution in that country when paired with the total number of vaccines distributed per country.
#
# In addition to the performing descriptive analysis:
#
#     -Vaccine distribution by country
#     -Total number of vaccines that have been distributed
#     -Confirmed cases, deaths
#     -Population comparison and vaccine distribution
#
# Some other interests came up during data cleaning.
#
#     -How much data is recorded for each of the 20 countries?
#     -Are there values for each day?
#
# There are negative values found in the active number of cases as a result of the fluctuation between confirmed, deaths, and recovered. A sum of COVID-19 transmission for each country will be compared to population of each country.
